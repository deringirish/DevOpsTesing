# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter


data = np.random.rand(100)
labels = ["Class1" if x <= 0.5 else "Class2" for x in data[:50]]


def euclidean_distance(x1, x2):
    return abs(x1 - x2)


def knn_classifier(train_data, train_labels, test_point, k):
    distances = [(euclidean_distance(test_point, train_data[i]), train_labels[i]) for i in range(len(train_data))]

    distances.sort(key=lambda x: x[0])
    
    k_nearest_neighbors = distances[:k]
    k_nearest_labels = [label for _, label in k_nearest_neighbors]
    return Counter(k_nearest_labels).most_common(1)[0][0] 



train_data = data[:50] 
train_labels = labels 
test_data = data[50:] 
k_values = [1, 2, 3, 4, 5, 20, 30] 
 
print("--- k-Nearest Neighbors Classification ---") 
print("Training dataset: First 50 points labeled based on the rule (x <= 0.5 -> Class1, x > 0.5 > Class2)") 
print("Testing dataset: Remaining 50 points to be classified\n") 
 
results = {} 
 
for k in k_values: 
    print(f"Results for k = {k}:") 
    classified_labels = [knn_classifier(train_data, train_labels, test_point, k) for test_point in test_data] 
    results[k] = classified_labels 
    for i, label in enumerate(classified_labels, start=51): 
        print(f"Point x{i} (value: {test_data[i - 51]:.4f}) is classified as {label}") 
          
          
print("\n") 
print("Classification complete.\n") 

 
for k in k_values: 
    classified_labels = results[k] 
    class1_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class1"] 
    class2_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class2"] 
 
    plt.figure(figsize=(10, 6)) 
    plt.scatter(train_data, [0] * len(train_data), c=["blue" if label == "Class1" else "red" for label in train_labels], label="Training Data", marker="o") 
    plt.scatter(class1_points, [1] * len(class1_points), c="blue", label="Class1 (Test)", marker="x") 
    plt.scatter(class2_points, [1] * len(class2_points), c="red", label="Class2 (Test)", marker="x") 
 
    plt.title(f"k-NN Classification Results for k = {k}") 
    plt.xlabel("Data Points") 
    plt.ylabel("Classification Level") 
    plt.legend() 
    plt.grid(True) 
    plt.show()
# Out:
# --- k-Nearest Neighbors Classification ---
# Training dataset: First 50 points labeled based on the rule (x <= 0.5 -> Class1, x > 0.5 > Class2)
# Testing dataset: Remaining 50 points to be classified
#
# Results for k = 1:
# Point x51 (value: 0.7583) is classified as Class2
# Point x52 (value: 0.7315) is classified as Class2
# Point x53 (value: 0.4529) is classified as Class1
# Point x54 (value: 0.4552) is classified as Class1
# Point x55 (value: 0.9181) is classified as Class2
# Point x56 (value: 0.9519) is classified as Class2
# Point x57 (value: 0.3393) is classified as Class1
# Point x58 (value: 0.4946) is classified as Class1
# Point x59 (value: 0.9349) is classified as Class2
# Point x60 (value: 0.8262) is classified as Class2
# Point x61 (value: 0.7330) is classified as Class2
# Point x62 (value: 0.9083) is classified as Class2
# Point x63 (value: 0.0858) is classified as Class1
# Point x64 (value: 0.5435) is classified as Class2
# Point x65 (value: 0.0145) is classified as Class1
# Point x66 (value: 0.0543) is classified as Class1
# Point x67 (value: 0.3674) is classified as Class1
# Point x68 (value: 0.8535) is classified as Class2
# Point x69 (value: 0.0075) is classified as Class1
# Point x70 (value: 0.8537) is classified as Class2
# Point x71 (value: 0.5604) is classified as Class2
# Point x72 (value: 0.0977) is classified as Class1
# Point x73 (value: 0.9594) is classified as Class2
# Point x74 (value: 0.9430) is classified as Class2
# Point x75 (value: 0.6010) is classified as Class2
# Point x76 (value: 0.3251) is classified as Class1
# Point x77 (value: 0.8087) is classified as Class2
# Point x78 (value: 0.3783) is classified as Class1
# Point x79 (value: 0.0832) is classified as Class1
# Point x80 (value: 0.1532) is classified as Class1
# Point x81 (value: 0.5220) is classified as Class2
# Point x82 (value: 0.3323) is classified as Class1
# Point x83 (value: 0.3119) is classified as Class1
# Point x84 (value: 0.8177) is classified as Class2
# Point x85 (value: 0.2279) is classified as Class1
# Point x86 (value: 0.9266) is classified as Class2
# Point x87 (value: 0.0944) is classified as Class1
# Point x88 (value: 0.0765) is classified as Class1
# Point x89 (value: 0.1860) is classified as Class1
# Point x90 (value: 0.1562) is classified as Class1
# Point x91 (value: 0.5669) is classified as Class2
# Point x92 (value: 0.8969) is classified as Class2
# Point x93 (value: 0.7980) is classified as Class2
# Point x94 (value: 0.5870) is classified as Class2
# Point x95 (value: 0.8068) is classified as Class2
# Point x96 (value: 0.1361) is classified as Class1
# Point x97 (value: 0.5070) is classified as Class2
# Point x98 (value: 0.1657) is classified as Class1
# Point x99 (value: 0.7980) is classified as Class2
# Point x100 (value: 0.5238) is classified as Class2
# Results for k = 2:
# Point x51 (value: 0.7583) is classified as Class2
# Point x52 (value: 0.7315) is classified as Class2
# Point x53 (value: 0.4529) is classified as Class1
# Point x54 (value: 0.4552) is classified as Class1
# Point x55 (value: 0.9181) is classified as Class2
# Point x56 (value: 0.9519) is classified as Class2
# Point x57 (value: 0.3393) is classified as Class1
# Point x58 (value: 0.4946) is classified as Class1
# Point x59 (value: 0.9349) is classified as Class2
# Point x60 (value: 0.8262) is classified as Class2
# Point x61 (value: 0.7330) is classified as Class2
# Point x62 (value: 0.9083) is classified as Class2
# Point x63 (value: 0.0858) is classified as Class1
# Point x64 (value: 0.5435) is classified as Class2
# Point x65 (value: 0.0145) is classified as Class1
# Point x66 (value: 0.0543) is classified as Class1
# Point x67 (value: 0.3674) is classified as Class1
# Point x68 (value: 0.8535) is classified as Class2
# Point x69 (value: 0.0075) is classified as Class1
# Point x70 (value: 0.8537) is classified as Class2
# Point x71 (value: 0.5604) is classified as Class2
# Point x72 (value: 0.0977) is classified as Class1
# Point x73 (value: 0.9594) is classified as Class2
# Point x74 (value: 0.9430) is classified as Class2
# Point x75 (value: 0.6010) is classified as Class2
# Point x76 (value: 0.3251) is classified as Class1
# Point x77 (value: 0.8087) is classified as Class2
# Point x78 (value: 0.3783) is classified as Class1
# Point x79 (value: 0.0832) is classified as Class1
# Point x80 (value: 0.1532) is classified as Class1
# Point x81 (value: 0.5220) is classified as Class2
# Point x82 (value: 0.3323) is classified as Class1
# Point x83 (value: 0.3119) is classified as Class1
# Point x84 (value: 0.8177) is classified as Class2
# Point x85 (value: 0.2279) is classified as Class1
# Point x86 (value: 0.9266) is classified as Class2
# Point x87 (value: 0.0944) is classified as Class1
# Point x88 (value: 0.0765) is classified as Class1
# Point x89 (value: 0.1860) is classified as Class1
# Point x90 (value: 0.1562) is classified as Class1
# Point x91 (value: 0.5669) is classified as Class2
# Point x92 (value: 0.8969) is classified as Class2
# Point x93 (value: 0.7980) is classified as Class2
# Point x94 (value: 0.5870) is classified as Class2
# Point x95 (value: 0.8068) is classified as Class2
# Point x96 (value: 0.1361) is classified as Class1
# Point x97 (value: 0.5070) is classified as Class2
# Point x98 (value: 0.1657) is classified as Class1
# Point x99 (value: 0.7980) is classified as Class2
# Point x100 (value: 0.5238) is classified as Class2
# Results for k = 3:
# Point x51 (value: 0.7583) is classified as Class2
# Point x52 (value: 0.7315) is classified as Class2
# Point x53 (value: 0.4529) is classified as Class1
# Point x54 (value: 0.4552) is classified as Class1
# Point x55 (value: 0.9181) is classified as Class2
# Point x56 (value: 0.9519) is classified as Class2
# Point x57 (value: 0.3393) is classified as Class1
# Point x58 (value: 0.4946) is classified as Class1
# Point x59 (value: 0.9349) is classified as Class2
# Point x60 (value: 0.8262) is classified as Class2
# Point x61 (value: 0.7330) is classified as Class2
# Point x62 (value: 0.9083) is classified as Class2
# Point x63 (value: 0.0858) is classified as Class1
# Point x64 (value: 0.5435) is classified as Class2
# Point x65 (value: 0.0145) is classified as Class1
# Point x66 (value: 0.0543) is classified as Class1
# Point x67 (value: 0.3674) is classified as Class1
# Point x68 (value: 0.8535) is classified as Class2
# Point x69 (value: 0.0075) is classified as Class1
# Point x70 (value: 0.8537) is classified as Class2
# Point x71 (value: 0.5604) is classified as Class2
# Point x72 (value: 0.0977) is classified as Class1
# Point x73 (value: 0.9594) is classified as Class2
# Point x74 (value: 0.9430) is classified as Class2
# Point x75 (value: 0.6010) is classified as Class2
# Point x76 (value: 0.3251) is classified as Class1
# Point x77 (value: 0.8087) is classified as Class2
# Point x78 (value: 0.3783) is classified as Class1
# Point x79 (value: 0.0832) is classified as Class1
# Point x80 (value: 0.1532) is classified as Class1
# Point x81 (value: 0.5220) is classified as Class2
# Point x82 (value: 0.3323) is classified as Class1
# Point x83 (value: 0.3119) is classified as Class1
# Point x84 (value: 0.8177) is classified as Class2
# Point x85 (value: 0.2279) is classified as Class1
# Point x86 (value: 0.9266) is classified as Class2
# Point x87 (value: 0.0944) is classified as Class1
# Point x88 (value: 0.0765) is classified as Class1
# Point x89 (value: 0.1860) is classified as Class1
# Point x90 (value: 0.1562) is classified as Class1
# Point x91 (value: 0.5669) is classified as Class2
# Point x92 (value: 0.8969) is classified as Class2
# Point x93 (value: 0.7980) is classified as Class2
# Point x94 (value: 0.5870) is classified as Class2
# Point x95 (value: 0.8068) is classified as Class2
# Point x96 (value: 0.1361) is classified as Class1
# Point x97 (value: 0.5070) is classified as Class1
# Point x98 (value: 0.1657) is classified as Class1
# Point x99 (value: 0.7980) is classified as Class2
# Point x100 (value: 0.5238) is classified as Class2
# Results for k = 4:
# Point x51 (value: 0.7583) is classified as Class2
# Point x52 (value: 0.7315) is classified as Class2
# Point x53 (value: 0.4529) is classified as Class1
# Point x54 (value: 0.4552) is classified as Class1
# Point x55 (value: 0.9181) is classified as Class2
# Point x56 (value: 0.9519) is classified as Class2
# Point x57 (value: 0.3393) is classified as Class1
# Point x58 (value: 0.4946) is classified as Class1
# Point x59 (value: 0.9349) is classified as Class2
# Point x60 (value: 0.8262) is classified as Class2
# Point x61 (value: 0.7330) is classified as Class2
# Point x62 (value: 0.9083) is classified as Class2
# Point x63 (value: 0.0858) is classified as Class1
# Point x64 (value: 0.5435) is classified as Class2
# Point x65 (value: 0.0145) is classified as Class1
# Point x66 (value: 0.0543) is classified as Class1
# Point x67 (value: 0.3674) is classified as Class1
# Point x68 (value: 0.8535) is classified as Class2
# Point x69 (value: 0.0075) is classified as Class1
# Point x70 (value: 0.8537) is classified as Class2
# Point x71 (value: 0.5604) is classified as Class2
# Point x72 (value: 0.0977) is classified as Class1
# Point x73 (value: 0.9594) is classified as Class2
# Point x74 (value: 0.9430) is classified as Class2
# Point x75 (value: 0.6010) is classified as Class2
# Point x76 (value: 0.3251) is classified as Class1
# Point x77 (value: 0.8087) is classified as Class2
# Point x78 (value: 0.3783) is classified as Class1
# Point x79 (value: 0.0832) is classified as Class1
# Point x80 (value: 0.1532) is classified as Class1
# Point x81 (value: 0.5220) is classified as Class2
# Point x82 (value: 0.3323) is classified as Class1
# Point x83 (value: 0.3119) is classified as Class1
# Point x84 (value: 0.8177) is classified as Class2
# Point x85 (value: 0.2279) is classified as Class1
# Point x86 (value: 0.9266) is classified as Class2
# Point x87 (value: 0.0944) is classified as Class1
# Point x88 (value: 0.0765) is classified as Class1
# Point x89 (value: 0.1860) is classified as Class1
# Point x90 (value: 0.1562) is classified as Class1
# Point x91 (value: 0.5669) is classified as Class2
# Point x92 (value: 0.8969) is classified as Class2
# Point x93 (value: 0.7980) is classified as Class2
# Point x94 (value: 0.5870) is classified as Class2
# Point x95 (value: 0.8068) is classified as Class2
# Point x96 (value: 0.1361) is classified as Class1
# Point x97 (value: 0.5070) is classified as Class1
# Point x98 (value: 0.1657) is classified as Class1
# Point x99 (value: 0.7980) is classified as Class2
# Point x100 (value: 0.5238) is classified as Class2
# Results for k = 5:
# Point x51 (value: 0.7583) is classified as Class2
# Point x52 (value: 0.7315) is classified as Class2
# Point x53 (value: 0.4529) is classified as Class1
# Point x54 (value: 0.4552) is classified as Class1
# Point x55 (value: 0.9181) is classified as Class2
# Point x56 (value: 0.9519) is classified as Class2
# Point x57 (value: 0.3393) is classified as Class1
# Point x58 (value: 0.4946) is classified as Class1
# Point x59 (value: 0.9349) is classified as Class2
# Point x60 (value: 0.8262) is classified as Class2
# Point x61 (value: 0.7330) is classified as Class2
# Point x62 (value: 0.9083) is classified as Class2
# Point x63 (value: 0.0858) is classified as Class1
# Point x64 (value: 0.5435) is classified as Class2
# Point x65 (value: 0.0145) is classified as Class1
# Point x66 (value: 0.0543) is classified as Class1
# Point x67 (value: 0.3674) is classified as Class1
# Point x68 (value: 0.8535) is classified as Class2
# Point x69 (value: 0.0075) is classified as Class1
# Point x70 (value: 0.8537) is classified as Class2
# Point x71 (value: 0.5604) is classified as Class2
# Point x72 (value: 0.0977) is classified as Class1
# Point x73 (value: 0.9594) is classified as Class2
# Point x74 (value: 0.9430) is classified as Class2
# Point x75 (value: 0.6010) is classified as Class2
# Point x76 (value: 0.3251) is classified as Class1
# Point x77 (value: 0.8087) is classified as Class2
# Point x78 (value: 0.3783) is classified as Class1
# Point x79 (value: 0.0832) is classified as Class1
# Point x80 (value: 0.1532) is classified as Class1
# Point x81 (value: 0.5220) is classified as Class1
# Point x82 (value: 0.3323) is classified as Class1
# Point x83 (value: 0.3119) is classified as Class1
# Point x84 (value: 0.8177) is classified as Class2
# Point x85 (value: 0.2279) is classified as Class1
# Point x86 (value: 0.9266) is classified as Class2
# Point x87 (value: 0.0944) is classified as Class1
# Point x88 (value: 0.0765) is classified as Class1
# Point x89 (value: 0.1860) is classified as Class1
# Point x90 (value: 0.1562) is classified as Class1
# Point x91 (value: 0.5669) is classified as Class2
# Point x92 (value: 0.8969) is classified as Class2
# Point x93 (value: 0.7980) is classified as Class2
# Point x94 (value: 0.5870) is classified as Class2
# Point x95 (value: 0.8068) is classified as Class2
# Point x96 (value: 0.1361) is classified as Class1
# Point x97 (value: 0.5070) is classified as Class1
# Point x98 (value: 0.1657) is classified as Class1
# Point x99 (value: 0.7980) is classified as Class2
# Point x100 (value: 0.5238) is classified as Class1
# Results for k = 20:
# Point x51 (value: 0.7583) is classified as Class2
# Point x52 (value: 0.7315) is classified as Class2
# Point x53 (value: 0.4529) is classified as Class1
# Point x54 (value: 0.4552) is classified as Class1
# Point x55 (value: 0.9181) is classified as Class2
# Point x56 (value: 0.9519) is classified as Class2
# Point x57 (value: 0.3393) is classified as Class1
# Point x58 (value: 0.4946) is classified as Class2
# Point x59 (value: 0.9349) is classified as Class2
# Point x60 (value: 0.8262) is classified as Class2
# Point x61 (value: 0.7330) is classified as Class2
# Point x62 (value: 0.9083) is classified as Class2
# Point x63 (value: 0.0858) is classified as Class1
# Point x64 (value: 0.5435) is classified as Class2
# Point x65 (value: 0.0145) is classified as Class1
# Point x66 (value: 0.0543) is classified as Class1
# Point x67 (value: 0.3674) is classified as Class1
# Point x68 (value: 0.8535) is classified as Class2
# Point x69 (value: 0.0075) is classified as Class1
# Point x70 (value: 0.8537) is classified as Class2
# Point x71 (value: 0.5604) is classified as Class2
# Point x72 (value: 0.0977) is classified as Class1
# Point x73 (value: 0.9594) is classified as Class2
# Point x74 (value: 0.9430) is classified as Class2
# Point x75 (value: 0.6010) is classified as Class2
# Point x76 (value: 0.3251) is classified as Class1
# Point x77 (value: 0.8087) is classified as Class2
# Point x78 (value: 0.3783) is classified as Class1
# Point x79 (value: 0.0832) is classified as Class1
# Point x80 (value: 0.1532) is classified as Class1
# Point x81 (value: 0.5220) is classified as Class2
# Point x82 (value: 0.3323) is classified as Class1
# Point x83 (value: 0.3119) is classified as Class1
# Point x84 (value: 0.8177) is classified as Class2
# Point x85 (value: 0.2279) is classified as Class1
# Point x86 (value: 0.9266) is classified as Class2
# Point x87 (value: 0.0944) is classified as Class1
# Point x88 (value: 0.0765) is classified as Class1
# Point x89 (value: 0.1860) is classified as Class1
# Point x90 (value: 0.1562) is classified as Class1
# Point x91 (value: 0.5669) is classified as Class2
# Point x92 (value: 0.8969) is classified as Class2
# Point x93 (value: 0.7980) is classified as Class2
# Point x94 (value: 0.5870) is classified as Class2
# Point x95 (value: 0.8068) is classified as Class2
# Point x96 (value: 0.1361) is classified as Class1
# Point x97 (value: 0.5070) is classified as Class2
# Point x98 (value: 0.1657) is classified as Class1
# Point x99 (value: 0.7980) is classified as Class2
# Point x100 (value: 0.5238) is classified as Class2
# Results for k = 30:
# Point x51 (value: 0.7583) is classified as Class2
# Point x52 (value: 0.7315) is classified as Class2
# Point x53 (value: 0.4529) is classified as Class1
# Point x54 (value: 0.4552) is classified as Class1
# Point x55 (value: 0.9181) is classified as Class2
# Point x56 (value: 0.9519) is classified as Class2
# Point x57 (value: 0.3393) is classified as Class1
# Point x58 (value: 0.4946) is classified as Class1
# Point x59 (value: 0.9349) is classified as Class2
# Point x60 (value: 0.8262) is classified as Class2
# Point x61 (value: 0.7330) is classified as Class2
# Point x62 (value: 0.9083) is classified as Class2
# Point x63 (value: 0.0858) is classified as Class1
# Point x64 (value: 0.5435) is classified as Class2
# Point x65 (value: 0.0145) is classified as Class1
# Point x66 (value: 0.0543) is classified as Class1
# Point x67 (value: 0.3674) is classified as Class1
# Point x68 (value: 0.8535) is classified as Class2
# Point x69 (value: 0.0075) is classified as Class1
# Point x70 (value: 0.8537) is classified as Class2
# Point x71 (value: 0.5604) is classified as Class2
# Point x72 (value: 0.0977) is classified as Class1
# Point x73 (value: 0.9594) is classified as Class2
# Point x74 (value: 0.9430) is classified as Class2
# Point x75 (value: 0.6010) is classified as Class2
# Point x76 (value: 0.3251) is classified as Class1
# Point x77 (value: 0.8087) is classified as Class2
# Point x78 (value: 0.3783) is classified as Class1
# Point x79 (value: 0.0832) is classified as Class1
# Point x80 (value: 0.1532) is classified as Class1
# Point x81 (value: 0.5220) is classified as Class2
# Point x82 (value: 0.3323) is classified as Class1
# Point x83 (value: 0.3119) is classified as Class1
# Point x84 (value: 0.8177) is classified as Class2
# Point x85 (value: 0.2279) is classified as Class1
# Point x86 (value: 0.9266) is classified as Class2
# Point x87 (value: 0.0944) is classified as Class1
# Point x88 (value: 0.0765) is classified as Class1
# Point x89 (value: 0.1860) is classified as Class1
# Point x90 (value: 0.1562) is classified as Class1
# Point x91 (value: 0.5669) is classified as Class2
# Point x92 (value: 0.8969) is classified as Class2
# Point x93 (value: 0.7980) is classified as Class2
# Point x94 (value: 0.5870) is classified as Class2
# Point x95 (value: 0.8068) is classified as Class2
# Point x96 (value: 0.1361) is classified as Class1
# Point x97 (value: 0.5070) is classified as Class2
# Point x98 (value: 0.1657) is classified as Class1
# Point x99 (value: 0.7980) is classified as Class2
# Point x100 (value: 0.5238) is classified as Class2
#
#
# Classification complete.
